# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Heart Failure Prediction Dataset

# %%
df_heartPrediction = pd.read_csv('heart.csv')
df_heartPrediction.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df_heartPrediction.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
df_heartPrediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df_heartPrediction.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df_heartPrediction.shape
# Out:
# (918, 12)

# %%
df_heartPrediction.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df_heartPrediction.nunique()
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %%
df_heartPrediction.count()
# Out:
# Age               918
# Sex               918
# ChestPainType     918
# RestingBP         918
# Cholesterol       918
# FastingBS         918
# RestingECG        918
# MaxHR             918
# ExerciseAngina    918
# Oldpeak           918
# ST_Slope          918
# HeartDisease      918
# dtype: int64

# %%
df_heartPrediction.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df_heartPrediction=df_heartPrediction.drop_duplicates(keep='first')
df_heartPrediction
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df_heartPrediction = df_heartPrediction.sort_values(by='Age', ascending=True)
df_heartPrediction
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 208   28   M           ATA        130          132          0        LVH
# 219   29   M           ATA        140          263          0     Normal
# 170   29   M           ATA        120          243          0     Normal
# 829   29   M           ATA        130          204          0        LVH
# 215   30   F            TA        170          237          0         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 491   75   M           ASY        170          203          1         ST
# 541   76   M           NAP        104          113          0        LVH
# 688   76   F           NAP        140          197          0         ST
# 814   77   M           ASY        125          304          0        LVH
# 447   77   M           ASY        124          171          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
# Histogram
df_heartPrediction.hist(bins=5, figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'RestingBP'}>,
#         <AxesSubplot:title={'center':'Cholesterol'}>],
#        [<AxesSubplot:title={'center':'FastingBS'}>,
#         <AxesSubplot:title={'center':'MaxHR'}>,
#         <AxesSubplot:title={'center':'Oldpeak'}>],
#        [<AxesSubplot:title={'center':'HeartDisease'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.distplot(df_heartPrediction['Age'], bins=10)
# Out:
# C:\Users\shrut\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
# Finding the relations between the variables using heatmap.
plt.figure(figsize=(20,10))
hmap= df_heartPrediction.corr()
sns.heatmap(hmap,cmap="BrBG",annot=True)
hmap
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.pairplot(df_heartPrediction,hue='HeartDisease')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df_heartPrediction["Age"], df_heartPrediction["RestingBP"])
ax.set_xlabel("Age")
ax.set_ylabel("RestingBP")
plt.show()

# %%
# Numerical values
df_heartPrediction1 = df_heartPrediction.select_dtypes(include=['int64','float64'])
df_heartPrediction1.head()
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 208   28        130          132          0    185      0.0             0
# 219   29        140          263          0    170      0.0             0
# 170   29        120          243          0    160      0.0             0
# 829   29        130          204          0    202      0.0             0
# 215   30        170          237          0    170      0.0             0

# %%
#Categorical values
df_heartPrediction1= df_heartPrediction.select_dtypes(include=['object'])
df_heartPrediction1.head()
# Out:
#     Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# 208   M           ATA        LVH              N       Up
# 219   M           ATA     Normal              N       Up
# 170   M           ATA     Normal              N       Up
# 829   M           ATA        LVH              N       Up
# 215   F            TA         ST              N       Up

# %%
df_heartPrediction.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
sns.boxplot(x=df_heartPrediction['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x=df_heartPrediction['RestingBP'])
# Out:
# <AxesSubplot:xlabel='RestingBP'>

# %%
sns.boxplot(x=df_heartPrediction['Cholesterol'])
# Out:
# <AxesSubplot:xlabel='Cholesterol'>

# %%
sns.boxplot(x=df_heartPrediction['FastingBS'])
# Out:
# <AxesSubplot:xlabel='FastingBS'>

# %%
sns.boxplot(x=df_heartPrediction['MaxHR'])
# Out:
# <AxesSubplot:xlabel='MaxHR'>

# %%
#Removing Outliers
Q1 = df_heartPrediction.quantile(0.25)
Q3 = df_heartPrediction.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Age             13.00
# RestingBP       20.00
# Cholesterol     93.75
# FastingBS        0.00
# MaxHR           36.00
# Oldpeak          1.50
# HeartDisease     1.00
# dtype: float64

# %%
df_heartPrediction = df_heartPrediction[~((df_heartPrediction < (Q1-1.5 * IQR)) |(df_heartPrediction > (Q3 + 1.5 * IQR))).any(axis=1)]
df_heartPrediction.shape
# Out:
# C:\Users\shrut\AppData\Local\Temp/ipykernel_28492/2301024660.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df_heart = df_heart[~((df_heart < (Q1-1.5 * IQR)) |(df_heart > (Q3 + 1.5 * IQR))).any(axis=1)]
# (588, 12)
